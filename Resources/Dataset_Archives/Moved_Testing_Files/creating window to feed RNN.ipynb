# %%
## starting model refinement and testing in this notebook 

# Import our dependencies
import pandas as pd
from datetime import datetime
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Read in our ramen data
CALI_df= pd.read_csv("../Resources/City_Zhvi_AllHomes.csv",parse_dates=True)
CALI_df
# Out:
#        Unnamed: 0  RegionID  SizeRank   RegionName RegionType StateName State  \
# 0               0      6181         0     New York       City        NY    NY
# 1               1     12447         1  Los Angeles       City        CA    CA
# 2               2     39051         2      Houston       City        TX    TX
# 3               3     17426         3      Chicago       City        IL    IL
# 4               4      6915         4  San Antonio       City        TX    TX
# ...           ...       ...       ...          ...        ...       ...   ...
# 27325       27325     48550     29449       Winton       City        MN    MN
# 27326       27326     51821     29449  Eastabuchie       City        MS    MS
# 27327       27327    232607     29449         Dean       City        TX    TX
# 27328       27328      6638     29449      Pulaski       City        GA    GA
# 27329       27329     33089     29449    New Paris       City        PA    PA
#
#                                   Metro          CountyName  1996-01-31  ...  \
# 0           New York-Newark-Jersey City       Queens County    196258.0  ...
# 1        Los Angeles-Long Beach-Anaheim  Los Angeles County    185649.0  ...
# 2      Houston-The Woodlands-Sugar Land       Harris County     93518.0  ...
# 3              Chicago-Naperville-Elgin         Cook County    130920.0  ...
# 4             San Antonio-New Braunfels        Bexar County     94041.0  ...
# ...                                 ...                 ...         ...  ...
# 27325                            Duluth  Saint Louis County         NaN  ...
# 27326                            Laurel        Jones County         NaN  ...
# 27327                     Wichita Falls         Clay County         NaN  ...
# 27328                               NaN      Candler County         NaN  ...
# 27329                               NaN      Bedford County         NaN  ...
#
#        2019-06-30  2019-07-31  2019-08-31  2019-09-30  2019-10-31  2019-11-30  \
# 0        659421.0    659007.0    658239.0    656925.0    655613.0    654394.0
# 1        712660.0    713807.0    715688.0    718245.0    721896.0    725180.0
# 2        186844.0    187464.0    188070.0    188496.0    189125.0    189612.0
# 3        248372.0    248646.0    248725.0    248483.0    248278.0    248090.0
# 4        182732.0    183350.0    183930.0    184846.0    185490.0    186244.0
# ...           ...         ...         ...         ...         ...         ...
# 27325     70929.0     70176.0     68979.0     68537.0     68948.0     69481.0
# 27326     77737.0     78461.0     79138.0     79930.0     79683.0     79838.0
# 27327    178872.0    179976.0    180654.0    181188.0    181613.0    182101.0
# 27328     97356.0     97757.0     98014.0     98225.0     98303.0     98613.0
# 27329     88745.0     89233.0     89169.0     89628.0     90073.0     90961.0
#
#        2019-12-31  2020-01-31  2020-02-29  2020-03-31
# 0        653930.0    653901.0    653565.0    652307.0
# 1        730358.0    735910.0    744137.0    752508.0
# 2        190179.0    190395.0    190938.0    191907.0
# 3        248029.0    248220.0    248599.0    249152.0
# 4        186420.0    186962.0    187129.0    187718.0
# ...           ...         ...         ...         ...
# 27325     69423.0     69355.0     69654.0     70399.0
# 27326     80272.0     80969.0     81871.0     82284.0
# 27327    182424.0    182764.0    182639.0    182361.0
# 27328     98802.0     99227.0     99699.0    100464.0
# 27329     91745.0     92232.0     92787.0     93564.0
#
# [27330 rows x 300 columns]

# %%
CALI_df=CALI_df[CALI_df["Metro"]=="San Francisco-Oakland-Hayward"]
CALI_df
# Out:
#        Unnamed: 0  RegionID  SizeRank     RegionName RegionType StateName  \
# 14             14     20330        14  San Francisco       City        CA
# 45             45     13072        45        Oakland       City        CA
# 114           114     11540       115        Fremont       City        CA
# 153           153     18518       155        Hayward       City        CA
# 256           256     51518       261        Concord       City        CA
# ...           ...       ...       ...            ...        ...       ...
# 23352       23352     19216     25745       Marshall       City        CA
# 23453       23453     49856     25861  Stinson Beach       City        CA
# 23732       23732     50048     26202        Tomales       City        CA
# 24071       24071     33838     26617   San Gregorio       City        CA
# 26119       26119     22508     29297       Loma Mar       City        CA
#
#       State                          Metro            CountyName  1996-01-31  \
# 14       CA  San Francisco-Oakland-Hayward  San Francisco County    297118.0
# 45       CA  San Francisco-Oakland-Hayward        Alameda County    156489.0
# 114      CA  San Francisco-Oakland-Hayward        Alameda County    223212.0
# 153      CA  San Francisco-Oakland-Hayward        Alameda County    163176.0
# 256      CA  San Francisco-Oakland-Hayward   Contra Costa County    161569.0
# ...     ...                            ...                   ...         ...
# 23352    CA  San Francisco-Oakland-Hayward          Marin County    450689.0
# 23453    CA  San Francisco-Oakland-Hayward          Marin County         NaN
# 23732    CA  San Francisco-Oakland-Hayward          Marin County    357380.0
# 24071    CA  San Francisco-Oakland-Hayward      San Mateo County         NaN
# 26119    CA  San Francisco-Oakland-Hayward      San Mateo County         NaN
#
#        ...  2019-06-30  2019-07-31  2019-08-31  2019-09-30  2019-10-31  \
# 14     ...   1399537.0   1401434.0   1399378.0   1403962.0   1409597.0
# 45     ...    759840.0    762928.0    766401.0    769974.0    772131.0
# 114    ...   1106611.0   1097388.0   1091681.0   1088331.0   1088897.0
# 153    ...    666488.0    664936.0    665113.0    665697.0    668112.0
# 256    ...    565471.0    563462.0    563033.0    560781.0    562229.0
# ...    ...         ...         ...         ...         ...         ...
# 23352  ...   1068318.0   1080588.0   1087160.0   1093587.0   1103958.0
# 23453  ...   3634878.0   3615747.0   3582735.0   3567322.0   3530804.0
# 23732  ...    817579.0    825220.0    822592.0    821673.0    823316.0
# 24071  ...   1295771.0   1292245.0   1298169.0   1305344.0   1305761.0
# 26119  ...    837063.0    832148.0    820779.0    815791.0    801524.0
#
#        2019-11-30  2019-12-31  2020-01-31  2020-02-29  2020-03-31
# 14      1418410.0   1431606.0   1438161.0   1445113.0   1447191.0
# 45       774320.0    780289.0    788547.0    795321.0    801072.0
# 114     1088933.0   1094414.0   1103557.0   1111111.0   1117349.0
# 153      669836.0    675350.0    682249.0    688301.0    693428.0
# 256      565749.0    569796.0    570141.0    569265.0    571879.0
# ...           ...         ...         ...         ...         ...
# 23352   1120680.0   1141395.0   1170287.0   1203885.0   1235143.0
# 23453   3497428.0   3462493.0   3459531.0   3482606.0   3541200.0
# 23732    828823.0    829744.0    826672.0    829849.0    833518.0
# 24071   1302290.0   1307477.0   1311276.0   1306738.0   1298783.0
# 26119    797276.0    798090.0    805132.0    811198.0    820985.0
#
# [100 rows x 300 columns]

# %%
## drop unneeded columns
## dropped RegionID, City, State, Metro, CountyName
CALI_df=CALI_df.drop(["Metro","CountyName","Unnamed: 0", "State", "SizeRank","RegionType","StateName","State"], axis=1)

# %%
##Rename RegionID to zipcode
CALI_df.rename(columns={"RegionID": 'Zipcode'}, inplace=True)
CALI_df.head()
# Out:
#      Zipcode     RegionName  1996-01-31  1996-02-29  1996-03-31  1996-04-30  \
# 14     20330  San Francisco    297118.0    296155.0    295503.0    294359.0
# 45     13072        Oakland    156489.0    155806.0    155488.0    154907.0
# 114    11540        Fremont    223212.0    222702.0    222584.0    222327.0
# 153    18518        Hayward    163176.0    162543.0    162383.0    162055.0
# 256    51518        Concord    161569.0    161011.0    161035.0    160695.0
#
#      1996-05-31  1996-06-30  1996-07-31  1996-08-31  ...  2019-06-30  \
# 14     293536.0    293161.0    292873.0    293344.0  ...   1399537.0
# 45     154761.0    154515.0    154268.0    154174.0  ...    759840.0
# 114    222526.0    222559.0    222674.0    223002.0  ...   1106611.0
# 153    162122.0    161927.0    161676.0    161527.0  ...    666488.0
# 256    160370.0    159739.0    159470.0    159800.0  ...    565471.0
#
#      2019-07-31  2019-08-31  2019-09-30  2019-10-31  2019-11-30  2019-12-31  \
# 14    1401434.0   1399378.0   1403962.0   1409597.0   1418410.0   1431606.0
# 45     762928.0    766401.0    769974.0    772131.0    774320.0    780289.0
# 114   1097388.0   1091681.0   1088331.0   1088897.0   1088933.0   1094414.0
# 153    664936.0    665113.0    665697.0    668112.0    669836.0    675350.0
# 256    563462.0    563033.0    560781.0    562229.0    565749.0    569796.0
#
#      2020-01-31  2020-02-29  2020-03-31
# 14    1438161.0   1445113.0   1447191.0
# 45     788547.0    795321.0    801072.0
# 114   1103557.0   1111111.0   1117349.0
# 153    682249.0    688301.0    693428.0
# 256    570141.0    569265.0    571879.0
#
# [5 rows x 293 columns]

# %%
##cast all zipcodes to string from integer
CALI_df["Zipcode"]=CALI_df["Zipcode"].astype(str)

# %%
## transpose dates to rows
CALI_df=CALI_df.transpose()
CALI_df.head()
# Out:
#                     14        45        114       153       256       298    \
# Zipcode             20330     13072     11540     18518     51518     16992
# RegionName  San Francisco   Oakland   Fremont   Hayward   Concord  Berkeley
# 1996-01-31       297118.0  156489.0  223212.0  163176.0  161569.0  236615.0
# 1996-02-29       296155.0  155806.0  222702.0  162543.0  161011.0  236272.0
# 1996-03-31       295503.0  155488.0  222584.0  162383.0  161035.0  236100.0
#
#                306       358          368        379    ...         20598  \
# Zipcode        26751     16780        13698      13699  ...         15366
# RegionName  Richmond   Antioch  San Leandro  San Mateo  ...  Dillon Beach
# 1996-01-31  194790.0  135223.0     171368.0   310087.0  ...      417552.0
# 1996-02-29  194565.0  134460.0     170780.0   309088.0  ...      415293.0
# 1996-03-31  193775.0  134109.0     170453.0   308646.0  ...      416379.0
#
#                 22365       22698         23054     23191     23352  \
# Zipcode          8646       56453         15926     42528     19216
# RegionName  Inverness  Port Costa  San Geronimo   Montara  Marshall
# 1996-01-31   388698.0         NaN      392920.0  338974.0  450689.0
# 1996-02-29   384619.0         NaN      386627.0  339045.0  446961.0
# 1996-03-31   384099.0         NaN      381710.0  339798.0  443290.0
#
#                     23453     23732         24071     26119
# Zipcode             49856     50048         33838     22508
# RegionName  Stinson Beach   Tomales  San Gregorio  Loma Mar
# 1996-01-31            NaN  357380.0           NaN       NaN
# 1996-02-29            NaN  357031.0           NaN       NaN
# 1996-03-31            NaN  357468.0           NaN       NaN
#
# [5 rows x 100 columns]

# %%
## dont want to do this add the columns are already correct just need to move the index over 

new_header=CALI_df.iloc[1] ##grab all first row data for the column headers
CALI_df=CALI_df[2:] ## take all rows after first row
CALI_df.columns=new_header ## assign all column headers to be equal to row 0 data
CALI_df.head()
# Out:
# RegionName San Francisco   Oakland   Fremont   Hayward   Concord  Berkeley  \
# 1996-01-31      297118.0  156489.0  223212.0  163176.0  161569.0  236615.0
# 1996-02-29      296155.0  155806.0  222702.0  162543.0  161011.0  236272.0
# 1996-03-31      295503.0  155488.0  222584.0  162383.0  161035.0  236100.0
# 1996-04-30      294359.0  154907.0  222327.0  162055.0  160695.0  235688.0
# 1996-05-31      293536.0  154761.0  222526.0  162122.0  160370.0  235451.0
#
# RegionName  Richmond   Antioch San Leandro San Mateo  ... Dillon Beach  \
# 1996-01-31  194790.0  135223.0    171368.0  310087.0  ...     417552.0
# 1996-02-29  194565.0  134460.0    170780.0  309088.0  ...     415293.0
# 1996-03-31  193775.0  134109.0    170453.0  308646.0  ...     416379.0
# 1996-04-30  192653.0  133387.0    169768.0  307550.0  ...     415465.0
# 1996-05-31  190735.0  132776.0    169371.0  306920.0  ...     418101.0
#
# RegionName Inverness Port Costa San Geronimo   Montara  Marshall  \
# 1996-01-31  388698.0        NaN     392920.0  338974.0  450689.0
# 1996-02-29  384619.0        NaN     386627.0  339045.0  446961.0
# 1996-03-31  384099.0        NaN     381710.0  339798.0  443290.0
# 1996-04-30  380603.0        NaN     374366.0  341162.0  434332.0
# 1996-05-31  380835.0        NaN     370725.0  342560.0  427407.0
#
# RegionName Stinson Beach   Tomales San Gregorio Loma Mar
# 1996-01-31           NaN  357380.0          NaN      NaN
# 1996-02-29           NaN  357031.0          NaN      NaN
# 1996-03-31           NaN  357468.0          NaN      NaN
# 1996-04-30           NaN  357985.0          NaN      NaN
# 1996-05-31           NaN  359463.0          NaN      NaN
#
# [5 rows x 100 columns]

# %%
## check that KNN imputer worked 

    
for column in CALI_df.columns:
    print(f"column {column} has {CALI_df[column].isnull().sum()} null values")
# Out:
# column San Francisco has 0 null values
# column Oakland has 0 null values
# column Fremont has 0 null values
# column Hayward has 0 null values
# column Concord has 0 null values
# column Berkeley has 0 null values
# column Richmond has 0 null values
# column Antioch has 0 null values
# column San Leandro has 0 null values
# column San Mateo has 0 null values
# column Daly City has 0 null values
# column Livermore has 0 null values
# column Redwood City has 0 null values
# column Pittsburg has 156 null values
# column Walnut Creek has 0 null values
# column San Ramon has 0 null values
# column Pleasanton has 0 null values
# column San Rafael has 0 null values
# column Union City has 0 null values
# column Brentwood has 0 null values
# column Alameda has 0 null values
# column South San Francisco has 0 null values
# column Novato has 0 null values
# column Danville has 0 null values
# column Castro Valley has 0 null values
# column Martinez has 0 null values
# column Dublin has 0 null values
# column Newark has 0 null values
# column Menlo Park has 0 null values
# column San Bruno has 0 null values
# column San Pablo has 0 null values
# column Oakley has 0 null values
# column Pacifica has 0 null values
# column Pleasant Hill has 0 null values
# column Foster City has 0 null values
# column Burlingame has 0 null values
# column San Carlos has 0 null values
# column Lafayette has 0 null values
# column San Lorenzo has 0 null values
# column Mill Valley has 0 null values
# column East Palo Alto has 0 null values
# column Belmont has 0 null values
# column El Cerrito has 0 null values
# column Millbrae has 0 null values
# column Hercules has 163 null values
# column Albany has 0 null values
# column Pinole has 0 null values
# column Orinda has 0 null values
# column Alamo has 0 null values
# column Moraga has 0 null values
# column Half Moon Bay has 0 null values
# column San Anselmo has 0 null values
# column Clayton has 0 null values
# column Sausalito has 0 null values
# column El Sobrante has 0 null values
# column Piedmont has 0 null values
# column Hillsborough has 0 null values
# column Woodside has 0 null values
# column Tiburon has 0 null values
# column North Fair Oaks has 0 null values
# column Emeryville has 0 null values
# column Corte Madera has 0 null values
# column Rodeo has 0 null values
# column Discovery Bay has 0 null values
# column Fairfax has 0 null values
# column Atherton has 0 null values
# column Kentfield has 0 null values
# column Larkspur has 0 null values
# column Kensington has 0 null values
# column Brisbane has 0 null values
# column Portola Valley has 0 null values
# column Highlands-Baywood Park has 0 null values
# column Emerald Lake Hills has 0 null values
# column Moss Beach has 0 null values
# column Ross has 0 null values
# column Bethel Island has 0 null values
# column Colma has 0 null values
# column San Quentin has 0 null values
# column Sunol has 0 null values
# column Belvedere has 0 null values
# column Crockett has 193 null values
# column Diablo has 0 null values
# column Pescadero has 16 null values
# column Point Reyes Station has 0 null values
# column Woodacre has 0 null values
# column Byron has 187 null values
# column Lagunitas has 0 null values
# column Canyon has 164 null values
# column Nicasio has 0 null values
# column La Honda has 0 null values
# column Dillon Beach has 0 null values
# column Inverness has 0 null values
# column Port Costa has 264 null values
# column San Geronimo has 0 null values
# column Montara has 0 null values
# column Marshall has 0 null values
# column Stinson Beach has 153 null values
# column Tomales has 0 null values
# column San Gregorio has 223 null values
# column Loma Mar has 164 null values

# %%
CALI_df.dropna(axis=1)
len(CALI_df)
# Out:
# 291

# %%
zips= CALI_df.columns.tolist()
len(zips)
# Out:
# 100

# %%
## dropping cities with nulls 

CALI_df.drop(columns=["Port Costa","Canyon","Crockett","Pittsburg"],inplace=True)

# %%
## check that KNN imputer worked 

    
for column in CALI_df.columns:
    print(f"column {column} has {CALI_df[column].isnull().sum()} null values")
# Out:
# column San Francisco has 0 null values
# column Oakland has 0 null values
# column Fremont has 0 null values
# column Hayward has 0 null values
# column Concord has 0 null values
# column Berkeley has 0 null values
# column Richmond has 0 null values
# column Antioch has 0 null values
# column San Leandro has 0 null values
# column San Mateo has 0 null values
# column Daly City has 0 null values
# column Livermore has 0 null values
# column Redwood City has 0 null values
# column Walnut Creek has 0 null values
# column San Ramon has 0 null values
# column Pleasanton has 0 null values
# column San Rafael has 0 null values
# column Union City has 0 null values
# column Brentwood has 0 null values
# column Alameda has 0 null values
# column South San Francisco has 0 null values
# column Novato has 0 null values
# column Danville has 0 null values
# column Castro Valley has 0 null values
# column Martinez has 0 null values
# column Dublin has 0 null values
# column Newark has 0 null values
# column Menlo Park has 0 null values
# column San Bruno has 0 null values
# column San Pablo has 0 null values
# column Oakley has 0 null values
# column Pacifica has 0 null values
# column Pleasant Hill has 0 null values
# column Foster City has 0 null values
# column Burlingame has 0 null values
# column San Carlos has 0 null values
# column Lafayette has 0 null values
# column San Lorenzo has 0 null values
# column Mill Valley has 0 null values
# column East Palo Alto has 0 null values
# column Belmont has 0 null values
# column El Cerrito has 0 null values
# column Millbrae has 0 null values
# column Hercules has 163 null values
# column Albany has 0 null values
# column Pinole has 0 null values
# column Orinda has 0 null values
# column Alamo has 0 null values
# column Moraga has 0 null values
# column Half Moon Bay has 0 null values
# column San Anselmo has 0 null values
# column Clayton has 0 null values
# column Sausalito has 0 null values
# column El Sobrante has 0 null values
# column Piedmont has 0 null values
# column Hillsborough has 0 null values
# column Woodside has 0 null values
# column Tiburon has 0 null values
# column North Fair Oaks has 0 null values
# column Emeryville has 0 null values
# column Corte Madera has 0 null values
# column Rodeo has 0 null values
# column Discovery Bay has 0 null values
# column Fairfax has 0 null values
# column Atherton has 0 null values
# column Kentfield has 0 null values
# column Larkspur has 0 null values
# column Kensington has 0 null values
# column Brisbane has 0 null values
# column Portola Valley has 0 null values
# column Highlands-Baywood Park has 0 null values
# column Emerald Lake Hills has 0 null values
# column Moss Beach has 0 null values
# column Ross has 0 null values
# column Bethel Island has 0 null values
# column Colma has 0 null values
# column San Quentin has 0 null values
# column Sunol has 0 null values
# column Belvedere has 0 null values
# column Diablo has 0 null values
# column Pescadero has 16 null values
# column Point Reyes Station has 0 null values
# column Woodacre has 0 null values
# column Byron has 187 null values
# column Lagunitas has 0 null values
# column Nicasio has 0 null values
# column La Honda has 0 null values
# column Dillon Beach has 0 null values
# column Inverness has 0 null values
# column San Geronimo has 0 null values
# column Montara has 0 null values
# column Marshall has 0 null values
# column Stinson Beach has 153 null values
# column Tomales has 0 null values
# column San Gregorio has 223 null values
# column Loma Mar has 164 null values

# %%
CALI_df.head()
# Out:
# RegionName San Francisco   Oakland   Fremont   Hayward   Concord  Berkeley  \
# 1996-01-31      297118.0  156489.0  223212.0  163176.0  161569.0  236615.0
# 1996-02-29      296155.0  155806.0  222702.0  162543.0  161011.0  236272.0
# 1996-03-31      295503.0  155488.0  222584.0  162383.0  161035.0  236100.0
# 1996-04-30      294359.0  154907.0  222327.0  162055.0  160695.0  235688.0
# 1996-05-31      293536.0  154761.0  222526.0  162122.0  160370.0  235451.0
#
# RegionName  Richmond   Antioch San Leandro San Mateo  ...  La Honda  \
# 1996-01-31  194790.0  135223.0    171368.0  310087.0  ...  496957.0
# 1996-02-29  194565.0  134460.0    170780.0  309088.0  ...  496014.0
# 1996-03-31  193775.0  134109.0    170453.0  308646.0  ...  497679.0
# 1996-04-30  192653.0  133387.0    169768.0  307550.0  ...  499765.0
# 1996-05-31  190735.0  132776.0    169371.0  306920.0  ...  501333.0
#
# RegionName Dillon Beach Inverness San Geronimo   Montara  Marshall  \
# 1996-01-31     417552.0  388698.0     392920.0  338974.0  450689.0
# 1996-02-29     415293.0  384619.0     386627.0  339045.0  446961.0
# 1996-03-31     416379.0  384099.0     381710.0  339798.0  443290.0
# 1996-04-30     415465.0  380603.0     374366.0  341162.0  434332.0
# 1996-05-31     418101.0  380835.0     370725.0  342560.0  427407.0
#
# RegionName Stinson Beach   Tomales San Gregorio Loma Mar
# 1996-01-31           NaN  357380.0          NaN      NaN
# 1996-02-29           NaN  357031.0          NaN      NaN
# 1996-03-31           NaN  357468.0          NaN      NaN
# 1996-04-30           NaN  357985.0          NaN      NaN
# 1996-05-31           NaN  359463.0          NaN      NaN
#
# [5 rows x 96 columns]

# %%
CALI_df.to_csv("../Resources/bay_area.csv", encoding='utf-8')

# %%
# sf but area code is wrong, IN = 47401

# removing last 20 for testing set 0:271
training_set = CALI_df.iloc[:271, 0:1].values
training_set
# Out:
# array([[297118.0],
#        [296155.0],
#        [295503.0],
#        [294359.0],
#        [293536.0],
#        [293161.0],
#        [292873.0],
#        [293344.0],
#        [294068.0],
#        [295381.0],
#        [296744.0],
#        [298433.0],
#        [300639.0],
#        [303292.0],
#        [306176.0],
#        [308820.0],
#        [311827.0],
#        [314768.0],
#        [318330.0],
#        [321488.0],
#        [324896.0],
#        [327974.0],
#        [331664.0],
#        [335688.0],
#        [339758.0],
#        [343928.0],
#        [347978.0],
#        [352602.0],
#        [357142.0],
#        [361805.0],
#        [366248.0],
#        [370465.0],
#        [374822.0],
#        [379186.0],
#        [383202.0],
#        [386443.0],
#        [389086.0],
#        [392224.0],
#        [395798.0],
#        [399688.0],
#        [403467.0],
#        [407765.0],
#        [412423.0],
#        [417729.0],
#        [422910.0],
#        [428667.0],
#        [435166.0],
#        [442790.0],
#        [451273.0],
#        [459100.0],
#        [467482.0],
#        [475803.0],
#        [485118.0],
#        [494384.0],
#        [504085.0],
#        [513705.0],
#        [523572.0],
#        [534415.0],
#        [546557.0],
#        [559933.0],
#        [571651.0],
#        [581682.0],
#        [587900.0],
#        [593538.0],
#        [596799.0],
#        [599294.0],
#        [599342.0],
#        [599070.0],
#        [599292.0],
#        [597823.0],
#        [594943.0],
#        [589121.0],
#        [586091.0],
#        [583579.0],
#        [584848.0],
#        [585829.0],
#        [591059.0],
#        [597554.0],
#        [605582.0],
#        [613868.0],
#        [619294.0],
#        [624386.0],
#        [627187.0],
#        [631470.0],
#        [633565.0],
#        [638532.0],
#        [643182.0],
#        [648530.0],
#        [647807.0],
#        [646711.0],
#        [647630.0],
#        [650975.0],
#        [654427.0],
#        [657305.0],
#        [663384.0],
#        [671324.0],
#        [683153.0],
#        [692912.0],
#        [702081.0],
#        [709626.0],
#        [720369.0],
#        [731533.0],
#        [741779.0],
#        [749690.0],
#        [761095.0],
#        [774877.0],
#        [788557.0],
#        [800056.0],
#        [808703.0],
#        [821536.0],
#        [831583.0],
#        [842577.0],
#        [850977.0],
#        [859748.0],
#        [868253.0],
#        [874735.0],
#        [882374.0],
#        [889915.0],
#        [894361.0],
#        [897922.0],
#        [898303.0],
#        [893783.0],
#        [889377.0],
#        [886003.0],
#        [888500.0],
#        [890806.0],
#        [891258.0],
#        [891458.0],
#        [888721.0],
#        [883880.0],
#        [880288.0],
#        [879524.0],
#        [881149.0],
#        [887250.0],
#        [893473.0],
#        [902299.0],
#        [904252.0],
#        [906266.0],
#        [906741.0],
#        [909534.0],
#        [911427.0],
#        [910911.0],
#        [911348.0],
#        [904619.0],
#        [899031.0],
#        [887022.0],
#        [882700.0],
#        [876240.0],
#        [874529.0],
#        [864924.0],
#        [854212.0],
#        [844404.0],
#        [838194.0],
#        [833496.0],
#        [826407.0],
#        [818523.0],
#        [810852.0],
#        [801402.0],
#        [791607.0],
#        [778855.0],
#        [768634.0],
#        [763965.0],
#        [764336.0],
#        [757958.0],
#        [748216.0],
#        [742820.0],
#        [742322.0],
#        [751264.0],
#        [756063.0],
#        [765060.0],
#        [764361.0],
#        [766430.0],
#        [764671.0],
#        [765324.0],
#        [759351.0],
#        [760435.0],
#        [761043.0],
#        [760482.0],
#        [754789.0],
#        [743439.0],
#        [735641.0],
#        [726810.0],
#        [723694.0],
#        [720706.0],
#        [716776.0],
#        [709466.0],
#        [706254.0],
#        [702980.0],
#        [702656.0],
#        [701160.0],
#        [701895.0],
#        [703393.0],
#        [702971.0],
#        [707730.0],
#        [713304.0],
#        [718732.0],
#        [723294.0],
#        [730619.0],
#        [742786.0],
#        [756369.0],
#        [770919.0],
#        [784565.0],
#        [795257.0],
#        [806072.0],
#        [822452.0],
#        [828161.0],
#        [836111.0],
#        [843687.0],
#        [863264.0],
#        [883546.0],
#        [897228.0],
#        [910703.0],
#        [917267.0],
#        [923085.0],
#        [928086.0],
#        [939693.0],
#        [949909.0],
#        [969559.0],
#        [984669.0],
#        [1000781.0],
#        [1007692.0],
#        [1009009.0],
#        [1012662.0],
#        [1009778.0],
#        [1012757.0],
#        [1018197.0],
#        [1036411.0],
#        [1046267.0],
#        [1051206.0],
#        [1060318.0],
#        [1075436.0],
#        [1093618.0],
#        [1101118.0],
#        [1116571.0],
#        [1136512.0],
#        [1159973.0],
#        [1180267.0],
#        [1195855.0],
#        [1199931.0],
#        [1209775.0],
#        [1225279.0],
#        [1232255.0],
#        [1228967.0],
#        [1214661.0],
#        [1214696.0],
#        [1208545.0],
#        [1198375.0],
#        [1187458.0],
#        [1186359.0],
#        [1192592.0],
#        [1204819.0],
#        [1210971.0],
#        [1212326.0],
#        [1208365.0],
#        [1207043.0],
#        [1215281.0],
#        [1228137.0],
#        [1241942.0],
#        [1256130.0],
#        [1271879.0],
#        [1286084.0],
#        [1294341.0],
#        [1302945.0],
#        [1310732.0],
#        [1319957.0],
#        [1332798.0],
#        [1355929.0],
#        [1377735.0],
#        [1387011.0],
#        [1399056.0],
#        [1405671.0]], dtype=object)

# %%
len(training_set)
# Out:
# 271

# %%
# Feature Scaling
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)

# %%
# Creating a data structure with 60 timesteps and 1 output
import numpy as np
X_train = []
y_train = []
for i in range(60, 271):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

# Reshaping
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
len(X_train)
# Out:
# 211

# %%
# Part 2 - Building the RNN

# Importing the Keras libraries and packages
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
# Initialising the RNN
regressor = Sequential()

# Adding the first LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))

# Adding a second LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# Adding a third LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# Adding a fourth LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))

# Adding the output layer
regressor.add(Dense(units = 1))

# Compiling the RNN
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
# Fitting the RNN to the Training set
regressor.fit(X_train, y_train, epochs = 150, batch_size = 32)
# Out:
# Epoch 1/150
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0028
# Epoch 2/150
# 7/7 [==============================] - 1s 82ms/step - loss: 0.0033
# Epoch 3/150
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0032
# Epoch 4/150
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0026
# Epoch 5/150
# 7/7 [==============================] - 1s 79ms/step - loss: 0.0034
# Epoch 6/150
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0032
# Epoch 7/150
# 7/7 [==============================] - 1s 79ms/step - loss: 0.0036
# Epoch 8/150
# 7/7 [==============================] - 1s 81ms/step - loss: 0.0037
# Epoch 9/150
# 7/7 [==============================] - 1s 81ms/step - loss: 0.0029
# Epoch 10/150
# 7/7 [==============================] - 1s 79ms/step - loss: 0.0033
# Epoch 11/150
# 7/7 [==============================] - 1s 81ms/step - loss: 0.0023
# Epoch 12/150
# 7/7 [==============================] - 1s 81ms/step - loss: 0.0028
# Epoch 13/150
# 7/7 [==============================] - 1s 82ms/step - loss: 0.0026
# Epoch 14/150
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0032
# Epoch 15/150
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0029
# Epoch 16/150
# 7/7 [==============================] - 1s 81ms/step - loss: 0.0028
# Epoch 17/150
# 7/7 [==============================] - 1s 81ms/step - loss: 0.0027
# Epoch 18/150
# 7/7 [==============================] - 1s 82ms/step - loss: 0.0022
# Epoch 19/150
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0032
# Epoch 20/150
# 7/7 [==============================] - 1s 81ms/step - loss: 0.0026
# Epoch 21/150
# 7/7 [==============================] - 1s 81ms/step - loss: 0.0026
# Epoch 22/150
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0038
# Epoch 23/150
# 7/7 [==============================] - 1s 77ms/step - loss: 0.0040
# Epoch 24/150
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0029
# Epoch 25/150
# 7/7 [==============================] - 0s 67ms/step - loss: 0.0033
# Epoch 26/150
# 7/7 [==============================] - 0s 66ms/step - loss: 0.0039
# Epoch 27/150
# 7/7 [==============================] - 0s 68ms/step - loss: 0.0029
# Epoch 28/150
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0027
# Epoch 29/150
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0029
# Epoch 30/150
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0029
# Epoch 31/150
# 7/7 [==============================] - 1s 76ms/step - loss: 0.0031
# Epoch 32/150
# 7/7 [==============================] - 1s 77ms/step - loss: 0.0032
# Epoch 33/150
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0029
# Epoch 34/150
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0022
# Epoch 35/150
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0028
# Epoch 36/150
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0027
# Epoch 37/150
# 7/7 [==============================] - 1s 71ms/step - loss: 0.0038
# Epoch 38/150
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0030
# Epoch 39/150
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0021
# Epoch 40/150
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0020
# Epoch 41/150
# 7/7 [==============================] - 1s 71ms/step - loss: 0.0027
# Epoch 42/150
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0026
# Epoch 43/150
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0028
# Epoch 44/150
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0022
# Epoch 45/150
# 7/7 [==============================] - 1s 70ms/step - loss: 0.0022
# Epoch 46/150
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0026
# Epoch 47/150
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0021
# Epoch 48/150
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0025
# Epoch 49/150
# 7/7 [==============================] - 1s 75ms/step - loss: 0.0022
# Epoch 50/150
# 7/7 [==============================] - 1s 76ms/step - loss: 0.0021
# Epoch 51/150
# 7/7 [==============================] - 1s 77ms/step - loss: 0.0024
# Epoch 52/150
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0029
# Epoch 53/150
# 7/7 [==============================] - 1s 81ms/step - loss: 0.0029
# Epoch 54/150
# 7/7 [==============================] - 1s 77ms/step - loss: 0.0026
# Epoch 55/150
# 7/7 [==============================] - 1s 73ms/step - loss: 0.0022
# Epoch 56/150
# 7/7 [==============================] - 1s 71ms/step - loss: 0.0028
# Epoch 57/150
# 7/7 [==============================] - 0s 63ms/step - loss: 0.0024
# Epoch 58/150
# 7/7 [==============================] - 0s 64ms/step - loss: 0.0027
# Epoch 59/150
# 7/7 [==============================] - 0s 66ms/step - loss: 0.0027
# Epoch 60/150
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0027
# Epoch 61/150
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0024
# Epoch 62/150
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0022
# Epoch 63/150
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0025
# Epoch 64/150
# 7/7 [==============================] - 1s 75ms/step - loss: 0.0021
# Epoch 65/150
# 7/7 [==============================] - 1s 79ms/step - loss: 0.0019
# Epoch 66/150
# 7/7 [==============================] - 1s 77ms/step - loss: 0.0017
# Epoch 67/150
# 7/7 [==============================] - 1s 77ms/step - loss: 0.0022
# Epoch 68/150
# 7/7 [==============================] - 1s 76ms/step - loss: 0.0022
# Epoch 69/150
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0023
# Epoch 70/150
# 7/7 [==============================] - 1s 77ms/step - loss: 0.0022
# Epoch 71/150
# 7/7 [==============================] - 1s 77ms/step - loss: 0.0029
# Epoch 72/150
# 7/7 [==============================] - 1s 76ms/step - loss: 0.0022
# Epoch 73/150
# 7/7 [==============================] - 1s 81ms/step - loss: 0.0026
# Epoch 74/150
# 7/7 [==============================] - 1s 82ms/step - loss: 0.0026
# Epoch 75/150
# 7/7 [==============================] - 1s 81ms/step - loss: 0.0024
# Epoch 76/150
# 7/7 [==============================] - 1s 81ms/step - loss: 0.0023
# Epoch 77/150
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0022
# Epoch 78/150
# 7/7 [==============================] - 1s 82ms/step - loss: 0.0027
# Epoch 79/150
# 7/7 [==============================] - 1s 82ms/step - loss: 0.0022
# Epoch 80/150
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0021
# Epoch 81/150
# 7/7 [==============================] - 1s 82ms/step - loss: 0.0025
# Epoch 82/150
# 7/7 [==============================] - 1s 81ms/step - loss: 0.0023
# Epoch 83/150
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0022
# Epoch 84/150
# 7/7 [==============================] - 1s 79ms/step - loss: 0.0021
# Epoch 85/150
# 7/7 [==============================] - 1s 77ms/step - loss: 0.0020
# Epoch 86/150
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0019
# Epoch 87/150
# 7/7 [==============================] - 0s 63ms/step - loss: 0.0025
# Epoch 88/150
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0030
# Epoch 89/150
# 7/7 [==============================] - 1s 74ms/step - loss: 0.0033
# Epoch 90/150
# 7/7 [==============================] - 1s 75ms/step - loss: 0.0025
# Epoch 91/150
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0020
# Epoch 92/150
# 7/7 [==============================] - 1s 79ms/step - loss: 0.0019
# Epoch 93/150
# 7/7 [==============================] - 1s 76ms/step - loss: 0.0019
# Epoch 94/150
# 7/7 [==============================] - 1s 75ms/step - loss: 0.0017
# Epoch 95/150
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0017
# Epoch 96/150
# 7/7 [==============================] - 1s 76ms/step - loss: 0.0018
# Epoch 97/150
# 7/7 [==============================] - 1s 77ms/step - loss: 0.0016
# Epoch 98/150
# 7/7 [==============================] - 1s 77ms/step - loss: 0.0019
# Epoch 99/150
# 7/7 [==============================] - 1s 77ms/step - loss: 0.0015
# Epoch 100/150
# 7/7 [==============================] - 1s 75ms/step - loss: 0.0017
# Epoch 101/150
# 7/7 [==============================] - 1s 77ms/step - loss: 0.0023
# Epoch 102/150
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0016
# Epoch 103/150
# 7/7 [==============================] - 1s 76ms/step - loss: 0.0020
# Epoch 104/150
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0027
# Epoch 105/150
# 7/7 [==============================] - 0s 68ms/step - loss: 0.0026
# Epoch 106/150
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0022
# Epoch 107/150
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0016
# Epoch 108/150
# 7/7 [==============================] - 1s 77ms/step - loss: 0.0020
# Epoch 109/150
# 7/7 [==============================] - 1s 73ms/step - loss: 0.0017
# Epoch 110/150
# 7/7 [==============================] - 1s 77ms/step - loss: 0.0017
# Epoch 111/150
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0017
# Epoch 112/150
# 7/7 [==============================] - 0s 66ms/step - loss: 0.0015
# Epoch 113/150
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0017
# Epoch 114/150
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0017
# Epoch 115/150
# 7/7 [==============================] - 1s 76ms/step - loss: 0.0018
# Epoch 116/150
# 7/7 [==============================] - 1s 79ms/step - loss: 0.0017
# Epoch 117/150
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0019
# Epoch 118/150
# 7/7 [==============================] - 0s 66ms/step - loss: 0.0019
# Epoch 119/150
# 7/7 [==============================] - 0s 67ms/step - loss: 0.0018
# Epoch 120/150
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0014
# Epoch 121/150
# 7/7 [==============================] - 0s 67ms/step - loss: 0.0015
# Epoch 122/150
# 7/7 [==============================] - 0s 67ms/step - loss: 0.0013
# Epoch 123/150
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0018
# Epoch 124/150
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0016
# Epoch 125/150
# 7/7 [==============================] - 1s 74ms/step - loss: 0.0015
# Epoch 126/150
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0017
# Epoch 127/150
# 7/7 [==============================] - 1s 77ms/step - loss: 0.0016
# Epoch 128/150
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0016
# Epoch 129/150
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0015
# Epoch 130/150
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0015
# Epoch 131/150
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0029
# Epoch 132/150
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0017
# Epoch 133/150
# 7/7 [==============================] - 0s 68ms/step - loss: 0.0016
# Epoch 134/150
# 7/7 [==============================] - 1s 71ms/step - loss: 0.0016
# Epoch 135/150
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0014
# Epoch 136/150
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0017
# Epoch 137/150
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0013
# Epoch 138/150
# 7/7 [==============================] - 1s 73ms/step - loss: 0.0012
# Epoch 139/150
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0014
# Epoch 140/150
# 7/7 [==============================] - 1s 74ms/step - loss: 0.0014
# Epoch 141/150
# 7/7 [==============================] - 1s 73ms/step - loss: 0.0015
# Epoch 142/150
# 7/7 [==============================] - 1s 75ms/step - loss: 0.0016
# Epoch 143/150
# 7/7 [==============================] - 1s 76ms/step - loss: 0.0016
# Epoch 144/150
# 7/7 [==============================] - 1s 73ms/step - loss: 0.0020
# Epoch 145/150
# 7/7 [==============================] - 0s 68ms/step - loss: 0.0016
# Epoch 146/150
# 7/7 [==============================] - 1s 72ms/step - loss: 0.0015
# Epoch 147/150
# 7/7 [==============================] - 1s 81ms/step - loss: 0.0016
# Epoch 148/150
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0012
# Epoch 149/150
# 7/7 [==============================] - 1s 74ms/step - loss: 0.0016
# Epoch 150/150
# 7/7 [==============================] - 1s 73ms/step - loss: 0.0017

# %%
# Part 3 - Making the predictions and visualising the results

# Getting the real stock price
dataset_test = pd.read_csv("../Resources/bay_area.csv")
dataset_test.head()
# Out:
#    Unnamed: 0  San Francisco   Oakland   Fremont   Hayward   Concord  \
# 0  1996-01-31       297118.0  156489.0  223212.0  163176.0  161569.0
# 1  1996-02-29       296155.0  155806.0  222702.0  162543.0  161011.0
# 2  1996-03-31       295503.0  155488.0  222584.0  162383.0  161035.0
# 3  1996-04-30       294359.0  154907.0  222327.0  162055.0  160695.0
# 4  1996-05-31       293536.0  154761.0  222526.0  162122.0  160370.0
#
#    Berkeley  Richmond   Antioch  San Leandro  ...  La Honda  Dillon Beach  \
# 0  236615.0  194790.0  135223.0     171368.0  ...  496957.0      417552.0
# 1  236272.0  194565.0  134460.0     170780.0  ...  496014.0      415293.0
# 2  236100.0  193775.0  134109.0     170453.0  ...  497679.0      416379.0
# 3  235688.0  192653.0  133387.0     169768.0  ...  499765.0      415465.0
# 4  235451.0  190735.0  132776.0     169371.0  ...  501333.0      418101.0
#
#    Inverness  San Geronimo   Montara  Marshall  Stinson Beach   Tomales  \
# 0   388698.0      392920.0  338974.0  450689.0            NaN  357380.0
# 1   384619.0      386627.0  339045.0  446961.0            NaN  357031.0
# 2   384099.0      381710.0  339798.0  443290.0            NaN  357468.0
# 3   380603.0      374366.0  341162.0  434332.0            NaN  357985.0
# 4   380835.0      370725.0  342560.0  427407.0            NaN  359463.0
#
#    San Gregorio  Loma Mar
# 0           NaN       NaN
# 1           NaN       NaN
# 2           NaN       NaN
# 3           NaN       NaN
# 4           NaN       NaN
#
# [5 rows x 97 columns]

# %%
real_housing_price = dataset_test.iloc[:, 1:2].values
real_housing_price
# Out:
# array([[ 297118.],
#        [ 296155.],
#        [ 295503.],
#        [ 294359.],
#        [ 293536.],
#        [ 293161.],
#        [ 292873.],
#        [ 293344.],
#        [ 294068.],
#        [ 295381.],
#        [ 296744.],
#        [ 298433.],
#        [ 300639.],
#        [ 303292.],
#        [ 306176.],
#        [ 308820.],
#        [ 311827.],
#        [ 314768.],
#        [ 318330.],
#        [ 321488.],
#        [ 324896.],
#        [ 327974.],
#        [ 331664.],
#        [ 335688.],
#        [ 339758.],
#        [ 343928.],
#        [ 347978.],
#        [ 352602.],
#        [ 357142.],
#        [ 361805.],
#        [ 366248.],
#        [ 370465.],
#        [ 374822.],
#        [ 379186.],
#        [ 383202.],
#        [ 386443.],
#        [ 389086.],
#        [ 392224.],
#        [ 395798.],
#        [ 399688.],
#        [ 403467.],
#        [ 407765.],
#        [ 412423.],
#        [ 417729.],
#        [ 422910.],
#        [ 428667.],
#        [ 435166.],
#        [ 442790.],
#        [ 451273.],
#        [ 459100.],
#        [ 467482.],
#        [ 475803.],
#        [ 485118.],
#        [ 494384.],
#        [ 504085.],
#        [ 513705.],
#        [ 523572.],
#        [ 534415.],
#        [ 546557.],
#        [ 559933.],
#        [ 571651.],
#        [ 581682.],
#        [ 587900.],
#        [ 593538.],
#        [ 596799.],
#        [ 599294.],
#        [ 599342.],
#        [ 599070.],
#        [ 599292.],
#        [ 597823.],
#        [ 594943.],
#        [ 589121.],
#        [ 586091.],
#        [ 583579.],
#        [ 584848.],
#        [ 585829.],
#        [ 591059.],
#        [ 597554.],
#        [ 605582.],
#        [ 613868.],
#        [ 619294.],
#        [ 624386.],
#        [ 627187.],
#        [ 631470.],
#        [ 633565.],
#        [ 638532.],
#        [ 643182.],
#        [ 648530.],
#        [ 647807.],
#        [ 646711.],
#        [ 647630.],
#        [ 650975.],
#        [ 654427.],
#        [ 657305.],
#        [ 663384.],
#        [ 671324.],
#        [ 683153.],
#        [ 692912.],
#        [ 702081.],
#        [ 709626.],
#        [ 720369.],
#        [ 731533.],
#        [ 741779.],
#        [ 749690.],
#        [ 761095.],
#        [ 774877.],
#        [ 788557.],
#        [ 800056.],
#        [ 808703.],
#        [ 821536.],
#        [ 831583.],
#        [ 842577.],
#        [ 850977.],
#        [ 859748.],
#        [ 868253.],
#        [ 874735.],
#        [ 882374.],
#        [ 889915.],
#        [ 894361.],
#        [ 897922.],
#        [ 898303.],
#        [ 893783.],
#        [ 889377.],
#        [ 886003.],
#        [ 888500.],
#        [ 890806.],
#        [ 891258.],
#        [ 891458.],
#        [ 888721.],
#        [ 883880.],
#        [ 880288.],
#        [ 879524.],
#        [ 881149.],
#        [ 887250.],
#        [ 893473.],
#        [ 902299.],
#        [ 904252.],
#        [ 906266.],
#        [ 906741.],
#        [ 909534.],
#        [ 911427.],
#        [ 910911.],
#        [ 911348.],
#        [ 904619.],
#        [ 899031.],
#        [ 887022.],
#        [ 882700.],
#        [ 876240.],
#        [ 874529.],
#        [ 864924.],
#        [ 854212.],
#        [ 844404.],
#        [ 838194.],
#        [ 833496.],
#        [ 826407.],
#        [ 818523.],
#        [ 810852.],
#        [ 801402.],
#        [ 791607.],
#        [ 778855.],
#        [ 768634.],
#        [ 763965.],
#        [ 764336.],
#        [ 757958.],
#        [ 748216.],
#        [ 742820.],
#        [ 742322.],
#        [ 751264.],
#        [ 756063.],
#        [ 765060.],
#        [ 764361.],
#        [ 766430.],
#        [ 764671.],
#        [ 765324.],
#        [ 759351.],
#        [ 760435.],
#        [ 761043.],
#        [ 760482.],
#        [ 754789.],
#        [ 743439.],
#        [ 735641.],
#        [ 726810.],
#        [ 723694.],
#        [ 720706.],
#        [ 716776.],
#        [ 709466.],
#        [ 706254.],
#        [ 702980.],
#        [ 702656.],
#        [ 701160.],
#        [ 701895.],
#        [ 703393.],
#        [ 702971.],
#        [ 707730.],
#        [ 713304.],
#        [ 718732.],
#        [ 723294.],
#        [ 730619.],
#        [ 742786.],
#        [ 756369.],
#        [ 770919.],
#        [ 784565.],
#        [ 795257.],
#        [ 806072.],
#        [ 822452.],
#        [ 828161.],
#        [ 836111.],
#        [ 843687.],
#        [ 863264.],
#        [ 883546.],
#        [ 897228.],
#        [ 910703.],
#        [ 917267.],
#        [ 923085.],
#        [ 928086.],
#        [ 939693.],
#        [ 949909.],
#        [ 969559.],
#        [ 984669.],
#        [1000781.],
#        [1007692.],
#        [1009009.],
#        [1012662.],
#        [1009778.],
#        [1012757.],
#        [1018197.],
#        [1036411.],
#        [1046267.],
#        [1051206.],
#        [1060318.],
#        [1075436.],
#        [1093618.],
#        [1101118.],
#        [1116571.],
#        [1136512.],
#        [1159973.],
#        [1180267.],
#        [1195855.],
#        [1199931.],
#        [1209775.],
#        [1225279.],
#        [1232255.],
#        [1228967.],
#        [1214661.],
#        [1214696.],
#        [1208545.],
#        [1198375.],
#        [1187458.],
#        [1186359.],
#        [1192592.],
#        [1204819.],
#        [1210971.],
#        [1212326.],
#        [1208365.],
#        [1207043.],
#        [1215281.],
#        [1228137.],
#        [1241942.],
#        [1256130.],
#        [1271879.],
#        [1286084.],
#        [1294341.],
#        [1302945.],
#        [1310732.],
#        [1319957.],
#        [1332798.],
#        [1355929.],
#        [1377735.],
#        [1387011.],
#        [1399056.],
#        [1405671.],
#        [1416603.],
#        [1417071.],
#        [1418097.],
#        [1413299.],
#        [1404710.],
#        [1405370.],
#        [1405419.],
#        [1405480.],
#        [1400771.],
#        [1402436.],
#        [1399537.],
#        [1401434.],
#        [1399378.],
#        [1403962.],
#        [1409597.],
#        [1418410.],
#        [1431606.],
#        [1438161.],
#        [1445113.],
#        [1447191.]])

# %%
training= dataset_test.iloc[0:271, 1:2]
print(len(training))
training
# Out:
# 271
#      San Francisco
# 0         297118.0
# 1         296155.0
# 2         295503.0
# 3         294359.0
# 4         293536.0
# ..             ...
# 266      1355929.0
# 267      1377735.0
# 268      1387011.0
# 269      1399056.0
# 270      1405671.0
#
# [271 rows x 1 columns]

# %%
# make DF to set up input for testing 

training = CALI_df.iloc[:, 0:1]
training.reset_index(drop=True, inplace=True)
training
# Out:
# RegionName San Francisco
# 0               297118.0
# 1               296155.0
# 2               295503.0
# 3               294359.0
# 4               293536.0
# ..                   ...
# 286            1418410.0
# 287            1431606.0
# 288            1438161.0
# 289            1445113.0
# 290            1447191.0
#
# [291 rows x 1 columns]

# %%
test = CALI_df.iloc[271:, 0:1]
test.reset_index(drop=True, inplace=True)
print(len(test))
test
# Out:
# 20
# RegionName San Francisco
# 0              1416603.0
# 1              1417071.0
# 2              1418097.0
# 3              1413299.0
# 4              1404710.0
# 5              1405370.0
# 6              1405419.0
# 7              1405480.0
# 8              1400771.0
# 9              1402436.0
# 10             1399537.0
# 11             1401434.0
# 12             1399378.0
# 13             1403962.0
# 14             1409597.0
# 15             1418410.0
# 16             1431606.0
# 17             1438161.0
# 18             1445113.0
# 19             1447191.0

# %%
type(test)
# Out:
# pandas.core.frame.DataFrame

# %%
type(training)
# Out:
# pandas.core.frame.DataFrame

# %%
# Getting the predicted stock price of 2017
dataset_total = pd.concat((training, test), axis = 0)
dataset_total
# Out:
# RegionName San Francisco
# 0               297118.0
# 1               296155.0
# 2               295503.0
# 3               294359.0
# 4               293536.0
# ..                   ...
# 15             1418410.0
# 16             1431606.0
# 17             1438161.0
# 18             1445113.0
# 19             1447191.0
#
# [311 rows x 1 columns]

# %%
inputs = dataset_total[len(dataset_total) - len(test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)

# %%
len(inputs)
# Out:
# 80

# %%
X_test = []

for i in range(60, 80):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_housing_price = regressor.predict(X_test)
predicted_housing_price = sc.inverse_transform(predicted_housing_price)

# %%
predicted_housing_price
# Out:
# array([[1478379.5],
#        [1485754.4],
#        [1487780.1],
#        [1484507.6],
#        [1477054.5],
#        [1466880.6],
#        [1455937.8],
#        [1446167.5],
#        [1439098.8],
#        [1435329. ],
#        [1434916.1],
#        [1437218.2],
#        [1441394.2],
#        [1446368.4],
#        [1451416.4],
#        [1456241.5],
#        [1461009.2],
#        [1466324.8],
#        [1472487.8],
#        [1479396.9]], dtype=float32)

# %%
forgraph=real_housing_price[271:]
forgraph
# Out:
# array([[1416603.],
#        [1417071.],
#        [1418097.],
#        [1413299.],
#        [1404710.],
#        [1405370.],
#        [1405419.],
#        [1405480.],
#        [1400771.],
#        [1402436.],
#        [1399537.],
#        [1401434.],
#        [1399378.],
#        [1403962.],
#        [1409597.],
#        [1418410.],
#        [1431606.],
#        [1438161.],
#        [1445113.],
#        [1447191.]])

# %%
import matplotlib.pyplot as plt
# Visualising the results
plt.plot(forgraph, color = 'red', label = 'Real housing Price')
plt.plot(predicted_housing_price, color = 'blue', label = 'Predicted housing Price')
plt.title('SF Housing Price Predictions')
plt.xlabel('Time')
plt.ylabel('Housing Price')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error
RNN_mse = mean_squared_error(forgraph,predicted_housing_price)
RNN_rmse=np.sqrt(RNN_mse)
print("mse :",RNN_mse)
print("rmse :",RNN_rmse)

from sklearn.metrics import mean_absolute_error
RNN_MAE = mean_absolute_error(forgraph,predicted_housing_price)
print("MAE :",RNN_MAE)
# Out:
# mse : 2347815056.784375
# rmse : 48454.257364904224
# MAE : 46000.9125

# %% [markdown]
#  the RNN is off by an average of 39 K over the 20 months of predictions, more tuning of hyper parameters
# such as amount of epochs
#  the number
