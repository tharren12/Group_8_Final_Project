# %%
# Import our dependencies
import pandas as pd


# Read in our ramen data
census_df = pd.read_csv("../Resources/censusdata2019.csv", )
# Read in our ramen data
census_df
# # Print out the Country value counts
# country_counts = ramen_df.Country.value_counts()
# country_counts
# Out:
#                   City          State       2010       2011       2012  \
# 0             New York       New York  8190209.0  8272948.0  8346693.0
# 1          Los Angeles     California  3795512.0  3820876.0  3851202.0
# 2              Chicago       Illinois  2697477.0  2708114.0  2719141.0
# 3              Houston          Texas  2100280.0  2126032.0  2161593.0
# 4              Phoenix        Arizona  1449038.0  1469796.0  1499274.0
# ...                ...            ...        ...        ...        ...
# 19494   Hillsview town   South Dakota        3.0        3.0        3.0
# 19495  White Rock town   South Dakota        3.0        3.0        3.0
# 19496    Gross village       Nebraska        2.0        2.0        2.0
# 19497      Lotsee town       Oklahoma        2.0        2.0        2.0
# 19498   Monowi village       Nebraska        1.0        1.0        1.0
#
#             2013       2014       2015       2016       2017       2018  \
# ...

# %%
census_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19499 entries, 0 to 19498
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   City             19499 non-null  object
#  1   State            19499 non-null  object
#  2   2010             19499 non-null  float64
#  3   2011             19499 non-null  float64
#  4   2012             19499 non-null  float64
#  5   2013             19499 non-null  float64
#  6   2014             19499 non-null  float64
#  7   2015             19499 non-null  float64
#  8   2016             19499 non-null  float64
#  9   2017             19499 non-null  float64
#  10  2018             19499 non-null  float64
#  11  2019.00          19499 non-null  float64
#  12  delta_19_10      19499 non-null  float64
#  13  delta_19_15      19499 non-null  float64
#  14  delta_15_10      19499 non-null  float64
#  15  first_half_inc   19499 non-null  int64
# ...

# %%
for column in census_df.columns:
    print(f"column {column} has {census_df[column].isnull().sum()} null values")
# Out:
# column City has 0 null values
# column State has 0 null values
# column 2010 has 0 null values
# column 2011 has 0 null values
# column 2012 has 0 null values
# column 2013 has 0 null values
# column 2014 has 0 null values
# column 2015 has 0 null values
# column 2016 has 0 null values
# column 2017 has 0 null values
# column 2018 has 0 null values
# column 2019.00 has 0 null values
# column delta_19_10 has 0 null values
# column delta_19_15 has 0 null values
# column delta_15_10 has 0 null values
# column first_half_inc has 0 null values
# column second_half_inc has 0 null values
# column decade_inc has 0 null values
# column max_yoy_growth has 0 null values
# column min_yoy_growth has 0 null values

# %%
census_df.describe()
# Out:
#                2010          2011          2012          2013          2014  \
# count  1.949900e+04  1.949900e+04  1.949900e+04  1.949900e+04  1.949900e+04
# mean   9.967206e+03  1.004706e+04  1.013012e+04  1.020798e+04  1.028841e+04
# std    8.030501e+04  8.109550e+04  8.189673e+04  8.253983e+04  8.312460e+04
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    3.710000e+02  3.700000e+02  3.690000e+02  3.680000e+02  3.670000e+02
# 50%    1.153000e+03  1.152000e+03  1.152000e+03  1.151000e+03  1.149000e+03
# 75%    4.644500e+03  4.655000e+03  4.650000e+03  4.667500e+03  4.694500e+03
# max    8.190209e+06  8.272948e+06  8.346693e+06  8.396091e+06  8.433806e+06
#
#                2015          2016          2017          2018       2019.00  \
# count  1.949900e+04  1.949900e+04  1.949900e+04  1.949900e+04  1.949900e+04
# mean   1.036999e+04  1.044659e+04  1.051077e+04  1.056210e+04  1.061002e+04
# ...

# %% [markdown]
# looking to remove outliers from PCA here

# %%
census_df["2010"].plot()
# Out:
# <AxesSubplot:>

# %%
census_df["2010"].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
census_df["2010"].plot(kind='hist',bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# reading_scores_df = student_data_df.loc[
#     (student_data_df["school_name"] == "Thomas High School")&
#     (student_data_df["grade"]== "9th")& 
#     (student_data_df["reading_score"] > 0), 
#     "reading_score"] = np.nan

# %%
census_df.describe()
# Out:
#                2010          2011          2012          2013          2014  \
# count  1.949900e+04  1.949900e+04  1.949900e+04  1.949900e+04  1.949900e+04
# mean   9.967206e+03  1.004706e+04  1.013012e+04  1.020798e+04  1.028841e+04
# std    8.030501e+04  8.109550e+04  8.189673e+04  8.253983e+04  8.312460e+04
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    3.710000e+02  3.700000e+02  3.690000e+02  3.680000e+02  3.670000e+02
# 50%    1.153000e+03  1.152000e+03  1.152000e+03  1.151000e+03  1.149000e+03
# 75%    4.644500e+03  4.655000e+03  4.650000e+03  4.667500e+03  4.694500e+03
# max    8.190209e+06  8.272948e+06  8.346693e+06  8.396091e+06  8.433806e+06
#
#                2015          2016          2017          2018       2019.00  \
# count  1.949900e+04  1.949900e+04  1.949900e+04  1.949900e+04  1.949900e+04
# mean   1.036999e+04  1.044659e+04  1.051077e+04  1.056210e+04  1.061002e+04
# ...

# %%
## there are duplicates even in small city. need to cut out duplicates before moving forward

# %%
census_df["City"].nunique()
# Out:
# 15494

# %%
len(census_df["City"])
# Out:
# 19499

# %%
census_df.drop_duplicates(subset="City",keep = False, inplace = True)

# %%
len(census_df)
# Out:
# 13235

# %%
19499-13235
# Out:
# 6264

# %%
## run small city now to shrink data set again 
small_cty = census_df.loc[(census_df["2010"] < 5000)].index
small_cty
# Out:
# Int64Index([ 2418,  2427,  2690,  2737,  2932,  3117,  3256,  3272,  3438,
#              3665,
#             ...
#             19489, 19490, 19491, 19492, 19493, 19494, 19495, 19496, 19497,
#             19498],
#            dtype='int64', length=10407)

# %%
len(small_cty["City"].unique())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15292/656120359.py in <module>
# ----> 1 len(small_cty["City"].unique())
#
# ~\.conda\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    4602         if is_scalar(key):
#    4603             key = com.cast_scalar_indexer(key, warn_float=True)
# -> 4604             return getitem(key)
#    4605
#    4606         if isinstance(key, slice):
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
small_cty.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15292/1647033944.py in <module>
# ----> 1 small_cty.describe()
#
# AttributeError: 'Int64Index' object has no attribute 'describe'

# %%
census_df.drop(small_cty, inplace = True)

# %%
len(census_df)
# Out:
# 2828

# %%
13235 - 6643
# Out:
# 6592

# %%
## standardizing not working
# census_df = census_df[census_df["2019.00"]>1000]

# %%
census_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2828 entries, 0 to 4989
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   City             2828 non-null   object
#  1   State            2828 non-null   object
#  2   2010             2828 non-null   float64
#  3   2011             2828 non-null   float64
#  4   2012             2828 non-null   float64
#  5   2013             2828 non-null   float64
#  6   2014             2828 non-null   float64
#  7   2015             2828 non-null   float64
#  8   2016             2828 non-null   float64
#  9   2017             2828 non-null   float64
#  10  2018             2828 non-null   float64
#  11  2019.00          2828 non-null   float64
#  12  delta_19_10      2828 non-null   float64
#  13  delta_19_15      2828 non-null   float64
#  14  delta_15_10      2828 non-null   float64
#  15  first_half_inc   2828 non-null   int64
# ...
