# %%
import pandas as pd

# %%
homes = pd.read_csv('/Users/mac/Downloads/All_Homes_cleansed.xls')

# %%
homes
# Out:
#        Unnamed: 0  SizeRank      RegionName    StateName          CountyName  \
# 0               0         0        New York     New York       Queens County
# 1               1         1     Los Angeles   California  Los Angeles County
# 2               2         2         Houston        Texas       Harris County
# 3               3         3         Chicago     Illinois         Cook County
# 4               4         4     San Antonio        Texas        Bexar County
# ...           ...       ...             ...          ...                 ...
# 15442       27315     29449   Village Mills        Texas        Tyler County
# 15443       27316     29449    Derby Center      Vermont      Orleans County
# 15444       27319     29449  Port Mansfield        Texas      Willacy County
# 15445       27326     29449     Eastabuchie  Mississippi        Jones County
# 15446       27327     29449            Dean        Texas         Clay County
#
# ...

# %%
list(homes.columns)
# Out:
# ['Unnamed: 0',
#  'SizeRank',
#  'RegionName',
#  'StateName',
#  'CountyName',
#  'Jan-10',
#  'Feb-10',
#  'Mar-10',
#  'Apr-10',
#  'May-10',
#  'Jun-10',
#  'Jul-10',
#  'Aug-10',
#  'Sep-10',
#  'Oct-10',
#  'Nov-10',
#  'Dec-10',
#  'Jan-11',
#  'Feb-11',
#  'Mar-11',
#  'Apr-11',
#  'May-11',
#  'Jun-11',
#  'Jul-11',
#  'Aug-11',
#  'Sep-11',
#  'Oct-11',
#  'Nov-11',
#  'Dec-11',
#  'Jan-12',
#  'Feb-12',
#  'Mar-12',
#  'Apr-12',
#  'May-12',
#  'Jun-12',
#  'Jul-12',
#  'Aug-12',
#  'Sep-12',
#  'Oct-12',
#  'Nov-12',
#  'Dec-12',
#  'Jan-13',
#  'Feb-13',
#  'Mar-13',
#  'Apr-13',
#  'May-13',
#  'Jun-13',
#  'Jul-13',
#  'Aug-13',
#  'Sep-13',
#  'Oct-13',
#  'Nov-13',
#  'Dec-13',
#  'Jan-14',
#  'Feb-14',
#  'Mar-14',
#  'Apr-14',
#  'May-14',
#  'Jun-14',
#  'Jul-14',
#  'Aug-14',
#  'Sep-14',
#  'Oct-14',
#  'Nov-14',
#  'Dec-14',
#  'Jan-15',
#  'Feb-15',
#  'Mar-15',
#  'Apr-15',
#  'May-15',
#  'Jun-15',
#  'Jul-15',
#  'Aug-15',
#  'Sep-15',
#  'Oct-15',
# ...

# %%
homes.describe()
# Out:
#          Unnamed: 0     SizeRank        Jan-10        Feb-10        Mar-10  \
# count  15447.000000  15447.00000  1.544700e+04  1.544700e+04  1.544700e+04
# mean   11841.281608  12725.53389  1.786179e+05  1.784194e+05  1.782851e+05
# std     7845.615541   8690.70567  1.729433e+05  1.731191e+05  1.734121e+05
# min        0.000000      0.00000  1.111400e+04  1.104200e+04  1.102100e+04
# 25%     4895.000000   5070.00000  8.745600e+04  8.740050e+04  8.734900e+04
# 50%    11063.000000  11615.00000  1.329600e+05  1.328680e+05  1.327400e+05
# 75%    18239.000000  19629.00000  2.070405e+05  2.069980e+05  2.065190e+05
# max    27327.000000  29449.00000  3.336179e+06  3.367030e+06  3.407339e+06
#
#              Apr-10        May-10        Jun-10        Jul-10        Aug-10  \
# count  1.544700e+04  1.544700e+04  1.544700e+04  1.544700e+04  1.544700e+04
# mean   1.782820e+05  1.782565e+05  1.780554e+05  1.776177e+05  1.771023e+05
# ...

# %%
(homes
 #.groupby('year')
 [['SizeRank', 'Jan-10']]
 #.mean()
 #.quantile(.99)
 .plot()
);

# %%
 ax1 = homes.plot.scatter(x='SizeRank',
                      y='Jan-10',
                      c='DarkBlue')

# %%
homes.swapaxes("index", "columns")
# Out:
#                     0                   1              2            3      \
# Unnamed: 0              0                   1              2            3
# SizeRank                0                   1              2            3
# RegionName       New York         Los Angeles        Houston      Chicago
# StateName        New York          California          Texas     Illinois
# CountyName  Queens County  Los Angeles County  Harris County  Cook County
# ...                   ...                 ...            ...          ...
# Nov-19             654394              725180         189612       248090
# Dec-19             653930              730358         190179       248029
# Jan-20             653901              735910         190395       248220
# Feb-20             653565              744137         190938       248599
# Mar-20             652307              752508         191907       249152
#
#                    4                    5                6             7      \
# ...

# %%
df = homes.iloc[1:2 , 5:]

# %%
df
# Out:
#      Jan-10    Feb-10    Mar-10    Apr-10    May-10    Jun-10    Jul-10  \
# 1  443474.0  441260.0  440817.0  441873.0  445830.0  444219.0  442515.0
#
#      Aug-10    Sep-10    Oct-10  ...  Jun-19  Jul-19  Aug-19  Sep-19  Oct-19  \
# 1  438684.0  435730.0  432400.0  ...  712660  713807  715688  718245  721896
#
#    Nov-19  Dec-19  Jan-20  Feb-20  Mar-20
# 1  725180  730358  735910  744137  752508
#
# [1 rows x 123 columns]

# %%
mf = df.swapaxes("index", "columns")

# %%
mf
# Out:
# <AxesSubplot:>

# %%
mf
# Out:
#                1
# Jan-10  443474.0
# Feb-10  441260.0
# Mar-10  440817.0
# Apr-10  441873.0
# May-10  445830.0
# ...          ...
# Nov-19  725180.0
# Dec-19  730358.0
# Jan-20  735910.0
# Feb-20  744137.0
# Mar-20  752508.0
#
# [123 rows x 1 columns]

# %%
df = df.rename(columns={'oldName1': 'newName1', 'oldName2': 'newName2'})

# %%
pd.DataFrame(mf)
# Out:
#                1
# Jan-10  443474.0
# Feb-10  441260.0
# Mar-10  440817.0
# Apr-10  441873.0
# May-10  445830.0
# ...          ...
# Nov-19  725180.0
# Dec-19  730358.0
# Jan-20  735910.0
# Feb-20  744137.0
# Mar-20  752508.0
#
# [123 rows x 1 columns]

# %%
df = mf.reset_index()

# %%
df
# Out:
#       index         1
# 0    Jan-10  443474.0
# 1    Feb-10  441260.0
# 2    Mar-10  440817.0
# 3    Apr-10  441873.0
# 4    May-10  445830.0
# ..      ...       ...
# 118  Nov-19  725180.0
# 119  Dec-19  730358.0
# 120  Jan-20  735910.0
# 121  Feb-20  744137.0
# 122  Mar-20  752508.0
#
# [123 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['Jan-10', 'Feb-10', 'Mar-10', 'Apr-10', 'May-10', 'Jun-10', 'Jul-10',
#        'Aug-10', 'Sep-10', 'Oct-10',
#        ...
#        'Jun-19', 'Jul-19', 'Aug-19', 'Sep-19', 'Oct-19', 'Nov-19', 'Dec-19',
#        'Jan-20', 'Feb-20', 'Mar-20'],
#       dtype='object', length=123)

# %%
df.plot()
# Out:
# <AxesSubplot:>
