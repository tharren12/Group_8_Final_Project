# %%
# Import dependencies
import pandas as pd
import numpy as np

# %%
# Read in data for Per capita income by city
all_homes_state_df = pd.read_csv("../Resources/Sale_Prices_City.csv")
all_homes_state_df
# Out:
#       CityID             CityName       StateName  SizeRank   2010-01  \
# 0       6181             New York        New York         1       NaN
# 1      12447          Los Angeles      California         2  359600.0
# 2      39051              Houston           Texas         3  135000.0
# 3      17426              Chicago        Illinois         4  229600.0
# 4       6915          San Antonio           Texas         5  130000.0
# ...      ...                  ...             ...       ...       ...
# 3723   40400         Port Bolivar           Texas      3724       NaN
# 3724  397820  Long Beach Township      New Jersey      3725       NaN
# 3725   37346       Beech Mountain  North Carolina      3726       NaN
# 3726   34991              Corolla  North Carolina      3727       NaN
# 3727   52829            La Vernia           Texas      3728       NaN
#
#        2010-02   2010-03   2010-04   2010-05   2010-06  ...   2019-06  \
# ...

# %%
#Check for nulls
for column in all_homes_state_df.columns:
    print(f"column {column} has {all_homes_state_df[column].isnull().sum()} null values")
# Out:
# column CityID has 0 null values
# column CityName has 0 null values
# column StateName has 0 null values
# column SizeRank has 0 null values
# column 2010-01 has 2151 null values
# column 2010-02 has 2144 null values
# column 2010-03 has 2137 null values
# column 2010-04 has 2123 null values
# column 2010-05 has 2101 null values
# column 2010-06 has 2070 null values
# column 2010-07 has 2060 null values
# column 2010-08 has 2047 null values
# column 2010-09 has 2031 null values
# column 2010-10 has 2028 null values
# column 2010-11 has 2025 null values
# column 2010-12 has 2014 null values
# column 2011-01 has 2002 null values
# column 2011-02 has 1989 null values
# column 2011-03 has 1976 null values
# column 2011-04 has 1943 null values
# column 2011-05 has 1905 null values
# column 2011-06 has 1874 null values
# column 2011-07 has 1851 null values
# column 2011-08 has 1835 null values
# column 2011-09 has 1816 null values
# column 2011-10 has 1797 null values
# ...
